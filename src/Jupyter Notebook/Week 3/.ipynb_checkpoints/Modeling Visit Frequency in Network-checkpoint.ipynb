# %% [markdown]
# # Modeling Visit Frequency in Network

# %% [markdown]
# Below is an example of tracking the number of numbers each node is visited in a randomly generated graph.

# %%
from mesa import Agent, Model
from mesa.time import SimultaneousActivation
import networkx as nx
import numpy as np
        
class NetworkAgent(Agent):
    """Agent traverses network as model"""
    def __init__(self, unique_id: int, model: NetworkModel, node=None):
        super().__init__(unique_id=unique_id, model=model)
        self.node = node
    
    def step(self):
        """Move to random neighbor on each step"""
        possible_next_nodes = [node for node in nx.all_neighbors(graph=self.model.network, node=self.node)]
        self.node = np.random.choice(a=possible_next_nodes, size=1)[0]
        print(type(self.node))
        print(self.node)
        
class NetworkModel(Model):
    """Model resembling a graph/network"""
    def __init__(self, network, N=10):
        self.number_of_agents = N
        self.network = network
        self.schedule = SimultaneousActivation(model=self)
        
        # adding agents
        for i in range(self.number_of_agents):
            agent = NetworkAgent(unique_id=i, model=self, node=list(self.network)[0])
            self.schedule.add(agent=agent)
            
    def step(self):
        """Advance model by one step"""
        self.schedule.step()

# %%
# DEBUGGING PURPOSES ONLY
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

G = nx.Graph()
G.add_node(node_for_adding='text', time='day', score=10)
print([G.nodes])
for n in G.nodes:
    print(type(n))

nx.draw(G=G)
plt.show()
# Out:
# [NodeView(('text',))]
# <class 'str'>

# %%
import matplotlib.pyplot as plt
import networkx as nx
from networkx.generators.random_graphs import fast_gnp_random_graph
import numpy as np
# %matplotlib inline

G = nx.fast_gnp_random_graph(n=20, p=0.8, seed=np.random.randint(0, 1000))
nx.draw(G=G)
plt.show()

nodes_visited = []

model = NetworkModel(network=G, N=10)
for i in range(model.number_of_agents):
    model.step()
# Out:
# <class 'numpy.int64'>
# 10
# <class 'numpy.int64'>
# 10
# <class 'numpy.int64'>
# 18
# <class 'numpy.int64'>
# 6
# <class 'numpy.int64'>
# 5
# <class 'numpy.int64'>
# 3
# <class 'numpy.int64'>
# 6
# <class 'numpy.int64'>
# 2
# <class 'numpy.int64'>
# 1
# <class 'numpy.int64'>
# 18
# <class 'numpy.int64'>
# 18
# <class 'numpy.int64'>
# 9
# <class 'numpy.int64'>
# 17
# <class 'numpy.int64'>
# 10
# <class 'numpy.int64'>
# 0
# <class 'numpy.int64'>
# 9
# <class 'numpy.int64'>
# 0
# <class 'numpy.int64'>
# 14
# <class 'numpy.int64'>
# 14
# <class 'numpy.int64'>
# 15
# <class 'numpy.int64'>
# 1
# <class 'numpy.int64'>
# 8
# <class 'numpy.int64'>
# 1
# <class 'numpy.int64'>
# 14
# <class 'numpy.int64'>
# 10
# <class 'numpy.int64'>
# 6
# <class 'numpy.int64'>
# 2
# <class 'numpy.int64'>
# 1
# <class 'numpy.int64'>
# 1
# <class 'numpy.int64'>
# 5
# <class 'numpy.int64'>
# 0
# <class 'numpy.int64'>
# 1
# <class 'numpy.int64'>
# 3
# <class 'numpy.int64'>
# 10
# <class 'numpy.int64'>
# 9
# ...

# %%
from sklearn.metrics import confusion_matrix 
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report 
  
actual = [1, 1, 0, 1, 0, 0, 1, 0, 0, 0] 
predicted = [1, 0, 0, 1, 0, 0, 1, 1, 1, 0] 
results = confusion_matrix(actual, predicted) 
  
print('Confusion Matrix :')
print(results) 
print('Accuracy Score :',accuracy_score(actual, predicted))
print('Report : ')
print(classification_report(actual, predicted))
# Out:
# Confusion Matrix :
# [[4 2]
#  [1 3]]
# Accuracy Score : 0.7
# Report :
#               precision    recall  f1-score   support
#
#            0       0.80      0.67      0.73         6
#            1       0.60      0.75      0.67         4
#
#     accuracy                           0.70        10
#    macro avg       0.70      0.71      0.70        10
# weighted avg       0.72      0.70      0.70        10

# %%
from sklearn.metrics import confusion_matrix
y_true = [2, 0, 2, 2, 0, 1]
y_pred = [0, 0, 2, 2, 0, 2]
print(confusion_matrix(y_true, y_pred))


y_true = ["node1", "node2", "node2", "node3", "node1", "node3"]
y_pred = ["node1", "node2", "node3", "node1", "node1", "node3"]
print(confusion_matrix(y_true, y_pred, labels=["node1", "node2", "node3"]))


tn, fp, fn, tp = confusion_matrix([0, 1, 0, 1], [1, 1, 1, 0]).ravel()
print(tn, fp, fn, tp)
# Out:
# [[2 0 0]
#  [0 0 1]
#  [1 0 2]]
# [[2 0 0]
#  [0 1 1]
#  [1 0 1]]
# 0 2 1 1
