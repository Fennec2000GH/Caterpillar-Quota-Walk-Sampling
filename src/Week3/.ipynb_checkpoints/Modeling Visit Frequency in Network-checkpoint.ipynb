# %% [markdown]
# # Modeling Visit Frequency in Network

# %% [markdown]
# Below is an example of tracking the number of numbers each node is visited in a randomly generated graph.

# %%
from mesa import Agent, Model
from mesa.time import SimultaneousActivation
import networkx as nx
import numpy as np

class NetworkAgent(Agent):
    """Agent traverses network as model"""
    def __init__(self, unique_id, model, node=None):
        super().__init__(unique_id=unique_id, model=model)
        self.node = node
    
    def step(self):
        """Move to random neighbor on each step"""
        node =  [n for n in self.network][np.random.randint(0, len(G.nodes))]
        
class NetworkModel(Model):
    """Model resembling a graph/network"""
    def __init__(self, network):
        self.network = network
        self.schedule = SimultaneousActivation(model=self)
        
        # adding agents
        for i in range(10):
            agent = NetworkAgent(unique_id=i, model=self, node=list(self.network)[0])
            self.schedule.add(agent=agent)
            
    def step(self):
        """Advance model by one step"""
        self.schedule.step()
# Out:
#   File "<ipython-input-27-e49ec434b5e0>", line 17
#     class NetworkModel(Model):
#         ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
import networkx as nx
from networkx.generators.random_graphs import fast_gnp_random_graph
import numpy as np
# %matplotlib inline

G = nx.fast_gnp_random_graph(n=20, p=0.8, seed=np.random.randint(0, 1000))
nx.draw(G=G)
plt.show()

nodes_visited = []

model = NetworkModel(network=G)
for i in range(10):
    model.step()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-956d867f5ed8> in <module>
#      13 model = NetworkModel(network=G)
#      14 for i in range(10):
# ---> 15     model.step()
#
# <ipython-input-23-aa18ec425931> in step(self)
#      28     def step(self):
#      29         """Advance model by one step"""
# ---> 30         self.schedule.step()
#
# /usr/local/anaconda3/lib/python3.7/site-packages/mesa/time.py in step(self)
#     136         agent_keys = list(self._agents.keys())
#     137         for agent_key in agent_keys:
# --> 138             self._agents[agent_key].step()
#     139         for agent_key in agent_keys:
#     140             self._agents[agent_key].advance()
#
# <ipython-input-23-aa18ec425931> in step(self)
#      13         """Move to random neighbor on each step"""
#      14         possible_moves = nx.neighbors(G=self.model.network, n=self.node)
# ---> 15         node = possible_moves[np.random.randint(0, len(list(possible_moves)))]
#      16
#      17 class NetworkModel(Model):
#
# TypeError: 'dict_keyiterator' object is not subscriptable
